# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage
from PIL import Image

# %%
#3a

vecU = [3, 1, 8]
vecV = [2, 7, 4]

np.dot(vecU, vecV)
# Out:
# 45

# %%
#3b

matA = [[1,7,2],[4,0,6],[1,3,8]]
matB = [[4,5,1],[0,1,2],[5,3,9]]

np.matmul(matA, matB)
# Out:
# array([[14, 18, 33],
#        [46, 38, 58],
#        [44, 32, 79]])

# %%
#3c
np.multiply(matA, matB)
# Out:
# array([[ 4, 35,  2],
#        [ 0,  0, 12],
#        [ 5,  9, 72]])

# %%
#3d
np.multiply(matA, vecU)
# Out:
# array([[ 3,  7, 16],
#        [12,  0, 48],
#        [ 3,  3, 64]])

# %%
#3e
np.transpose(np.multiply(vecV, np.transpose(matB)))
# Out:
# array([[ 8, 10,  2],
#        [ 0,  7, 14],
#        [20, 12, 36]])

# %%
#4a
img1 = mpimg.imread('image1.jpg')
img2 = mpimg.imread('image2.jpg')
imgplot = plt.imshow(img1)
plt.show()
imgplot2 = plt.imshow(img2)
plt.show()

# %%
#4b

# %%
#crop1 = img1[1000][1000][2]
crop1 = img1[100: 1100,1100: 2100, :]

imgplot = plt.imshow(crop1)

plt.savefig('image1_crop.jpg')

plt.show()

# %%
#crop1Rotate = np.transpose(crop1)

crop1Rotate = ndimage.rotate(crop1, 90)

imgplot = plt.imshow(crop1Rotate)

plt.savefig('image1_crop_rotated.jpg')

plt.show()

# %%
new2 = np.array(img2)
new2[100: 1100,100: 1100, :] = crop1Rotate

imgplot = plt.imshow(new2)

plt.savefig('image2_pasted.jpg')

plt.show()

# %%
size=[512,512]
resize1 = Image.open('image1.jpg').resize(size)
imgplot = plt.imshow(resize1)
resize1.save('resize-output1.jpg')

size=[512,512]
resize2 = Image.open('image2.jpg').resize(size)
imgplot = plt.imshow(resize2)
resize2.save('resize-output2.jpg')

# %%
resize1.size
# Out:
# (512, 512)

# %%
#4c

# %%
halfing1 = np.array(resize1)
halfing2 = np.array(resize2)
halfing2[0: 256,0: 512, :] = halfing1[0: 256,0: 512, :]

# %%
imgplot = plt.imshow(halfing2)
plt.show()

# %%
#5a

# %%
grey = Image.open('svd_test.jpg').convert('L')
imgplot = plt.imshow(grey)
grey.save('greyscale.jpg')

# %%
#5b

# %%
U, sigma, V = np.linalg.svd(grey)

# %%
U.shape
# Out:
# (531, 531)

# %%
#RANK IS 531
sigma.shape
# Out:
# (531,)

# %%
V.shape
# Out:
# (800, 800)

# %%
imgplot = plt.imshow(grey)
plt.show()

# %%
n = [1, 5, 20, 100]

nScaled = np.matmul( np.matmul( U[:,:n[0]], np.diag(sigma[:n[0]]) ), V[:n[0], :] )

# %%
plt.savefig('rank_1_approx.jpg')

imgplot = plt.imshow(nScaled, cmap='gray')

plt.show()

# %%
#5c

# %%
nScaled = np.matmul( np.matmul( U[:,:n[1]], np.diag(sigma[:n[1]]) ), V[:n[1], :] ) 

plt.savefig('rank_5_approx.jpg')

imgplot = plt.imshow(nScaled, cmap='gray')
plt.show()

# %%
nScaled = np.matmul( np.matmul( U[:,:n[2]], np.diag(sigma[:n[2]]) ), V[:n[2], :] ) 

plt.savefig('rank_20_approx.jpg')

imgplot = plt.imshow(nScaled, cmap='gray')
plt.show()

# %%
nScaled = np.matmul( np.matmul( U[:,:n[3]], np.diag(sigma[:n[3]]) ), V[:n[3], :] ) 

plt.savefig('rank_100_approx.jpg')

imgplot = plt.imshow(nScaled, cmap='gray')
plt.show()
